# %% [markdown]
# # Ejercicios de matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Gráfica una recta de (-7,-7) a (7,7) de color rosa

# %%
plt.plot([-7,7], [-7,7], color = 'pink')

# %% [markdown]
# ## 2. Obtén el siguiente resultado utilizando subplot y la ecuación anterior

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.subplot(2,2,1)  
plt.plot([-7,7], [-7,7], color="pink")  
plt.subplot(2,2,2)  
plt.plot([-7,7], [-7,7], color="blue")  
plt.subplot(2,2,3)  
plt.plot([-7,7], [-7,7], color="red")  
plt.subplot(2,2,4)  
plt.plot([-7,7], [-7,7], color="magenta")  

plt.show()

# %% [markdown]
# ## 3. Obtén la siguiente gráfica de barras

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
et = ['a','b','c','d']
val = [10,20,30,40]

plt.bar(et,val, color = ['blue','yellow','aqua','magenta'])
plt.show()

# %% [markdown]
# ## 4. Obtener la siguiente gráfica

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(9,6))
etiquetas=["a","b","c","d"] #eje x
valores=[10,20,30,40]
valores1=[20,30,40,50]

x = np.arange(len(etiquetas))  #0,1,2,3 
ancho=0.5

plt.bar(x - ancho/2, valores, ancho, color="aqua") # para colocarlas movida a un lado , primera barra en -0,2 
plt.bar(x + ancho/2, valores1, ancho ,color="magenta")

ax.set_xticks(x) #los puntitos sobresalientes en x
ax.set_xticklabels(etiquetas)
# Out:
# [Text(0, 0, 'a'), Text(0, 0, 'b'), Text(0, 0, 'c'), Text(0, 0, 'd')]

# %% [markdown]
# ## 5. Obtener el histograma del último atributo del dataset de la iris plant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.hist(iris.iloc[:,3], bins = 30,color = 'magenta')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## 6. Muestra los histogramas de los últimos dos atributos de la iris plant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(iris.iloc[:,2], bins = 20, alpha = 0.4, color = 'magenta')
plt.hist(iris.iloc[:,3], bins = 20, alpha = 0.8, color = 'aqua')
plt.show()

# %% [markdown]
# ## 7. Guarda el dataset de titanic en una variable

# %%
df1 = pd.read_csv('titanic 1.csv')
df2 = pd.read_csv('titanic 2.csv')
df = pd.merge(df1,df2,on = 'PassengerId')
df.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  Survived  Pclass            Ticket     Fare
# 0  22.0         0       3         A/5 21171   7.2500
# 1  38.0         1       1          PC 17599  71.2833
# 2  26.0         1       3  STON/O2. 3101282   7.9250
# 3  35.0         1       1            113803  53.1000
# 4  35.0         0       3            373450   8.0500

# %% [markdown]
# ## 8. Muestra en una grafica de barras el número de hombres y mujeres que sobrevivieron

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hombres = len(df[(df['Sex']=='male') &( df['Survived'] == 1)]) # hombres 
hombres
# Out:
# 109

# %%
mujeres = len(df[(df['Sex']=='female') &( df['Survived'] == 1)]) # mujeres

# %%
eq = ['Hombres', 'Mujeres']

# %%
plt.bar(eq, [len(df[(df['Sex']=='male') &( df['Survived'] == 1)]), len(df[(df['Sex']=='female') &( df['Survived'] == 1)])],color = 'Green')
# Out:
# <BarContainer object of 2 artists>

# %%
valores = [hombres,mujeres]

# %%
plt.bar(eq, valores,color = 'Green')
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ## 9. Muestra en una grafica de barras agrupada la cantidad de hombres y mujeres que sobrevivieron y la cantidad de los que no sobrevivieron

# %%
et = ['mujeres', 'hombres']

# %%
hombres_s = len(df[(df['Sex']=='male') &( df['Survived'] == 1)]) 
mujeres_s = len(df[(df['Sex']=='female') &( df['Survived'] == 1)])
valores = [mujeres_s, hombres_s]

# %%
hombres_s
# Out:
# 109

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hombres_no_s = len(df[(df['Sex']=='male') &( df['Survived'] == 0)]) 
mujeres_no_s = len(df[(df['Sex']=='female') &( df['Survived'] == 0)])
valores1 = [mujeres_no_s, hombres_no_s]

# %%
hombres_no_s
# Out:
# 468

# %%
x = np.arange(len(et))
ancho=0.4

# %%
x
# Out:
# array([0, 1])

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.bar(x - ancho/2, valores, ancho, color = 'blue')
plt.bar(x+ ancho/2, valores1, ancho, color = 'red')

ax.set_xticks(x)
ax.set_xticklabels(et) #poner a bc d 
plt.show()

# %% [markdown]
# ## 10. Muestra en una grafica de barras agrupada la cantidad de hombres y mujeres de cada clase (Pclass)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hombres1 = df[(df['Sex'] == 'male') & (df['Pclass'] == 1)]
hombres1 = len(hombres1)
hombres1
# Out:
# 122

# %%
hombres2 = df[(df['Sex'] == 'male') & (df['Pclass'] == 2)]
hombres2 = len(hombres2)
hombres2
# Out:
# 108

# %%
hombres3 = df[(df['Sex'] == 'male') & (df['Pclass'] == 3)]
hombres3 = len(hombres3)
hombres3
# Out:
# 347

# %%
mujeres1 = df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]
mujeres1  =len(mujeres1)
mujeres1
# Out:
# 94

# %%
mujeres2 = df[(df['Sex'] == 'female') & (df['Pclass'] == 2)]
mujeres2  =len(mujeres2)
mujeres2
# Out:
# 76

# %%
mujeres3 = df[(df['Sex'] == 'female') & (df['Pclass'] == 3)]
mujeres3  =len(mujeres3)
mujeres3
# Out:
# 144

# %%
fig, ax = plt.subplots(figsize=(8,6))
et = ['hombres', 'mujeres']
x = np.arange(len(et))
ancho = 0.2
plt.bar(x - ancho, [hombres1, mujeres1], ancho, color = 'Blue')
plt.bar(x + ancho/2 , [hombres2, mujeres2], ancho, color = 'Red')
plt.bar(x + 2*ancho, [hombres3, mujeres3], ancho, color = 'Green')
ax.set_xticks(x) 
ax.set_xticklabels(et)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-16b600698730> in <module>
#       1 et = ['hombres', 'mujeres']
# ----> 2 x = np.arange(len(et))
#       3 ancho = 0.2
#       4 plt.figure(figsize=(8,4))
#       5 plt.bar(x - ancho, [hombres1, mujeres1], ancho, color = 'Blue')
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## 11. Muestra en una gráfica el número de sobrevivientes por clase (Pclass)

# %%
sobr1 = len(df[(df['Survived']==1) & (df['Pclass'] == 1)])
sobr1
sobr2 = len(df[(df['Survived']==1) & (df['Pclass'] == 2)])
sobr3 = len(df[(df['Survived']==1) & (df['Pclass'] == 3)])
et = ['Clase1' , 'Clase2', 'Clase3']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.bar(et, [sobr1,sobr2,sobr3], color = ['blue','green','red'])
plt.show()

# %% [markdown]
# ## 12. Muestra en una gráfica de sectores el número de los que no sobrevivieron por clase (Pclass)

# %%
![image.png](attachment:image.png)
# Out:
# '[image.png]' is not recognized as an internal or external command,
# operable program or batch file.

# %%
nosobr1 = len(df[(df['Survived']==0) & (df['Pclass'] == 1)])
nosobr2 = len(df[(df['Survived']==0) & (df['Pclass'] == 2)])
nosobr3 = len(df[(df['Survived']==0) & (df['Pclass'] == 3)])

# %%
fig, ax = plt.subplots(figsize=(8,6))
et = ['Clase 1', 'Clase 2', 'Clase 3']
valores = [nosobr1, nosobr2, nosobr3]
colores = ['pink', 'beige', 'yellow']
plt.pie(valores, labels = et, colors = colores, shadow = True,  explode = (0.1, 0.1, 0.0), autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ## 13. Muestra en 2 graficas de sectores con subplots() la siguiente información
#     1. En la primera gráfica mostrar el número de pasajeros que murieron de cada clase
#     2. En la segunda gráfica mostrar el número de pasajeros que sobrevivieron de cada clase

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.subplot(1,2,1)  
plt.pie(valores, labels = et, colors = colores, shadow = True,  explode = (0.1, 0.1, 0.0), autopct = '%1.2f%%')
plt.title('No sobrevivientes por clase') 
plt.subplot(1,2,2)  
plt.pie(valores1, labels = et, colors = colores, shadow = True,  explode = (0.1, 0.1, 0.1), autopct = '%1.2f%%')
plt.title('Sobrevivientes por clase') 
plt.show()

# %%
sobr1 = len(df[(df['Survived']==1) & (df['Pclass'] == 1)])
sobr2 = len(df[(df['Survived']==1) & (df['Pclass'] == 2)])
sobr3 = len(df[(df['Survived']==1) & (df['Pclass'] == 3)])
et = ['Clase 1', 'Clase 2', 'Clase 3']
valores1 = [sobr1,sobr2,sobr3]

# %% [markdown]
# ## 14. Muestra en una gráfica lineal las edades de los pasajeros que sobrevivieron y en otra la de los pasajeros que no sobrevivieron

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_1 = df[df['Survived']==1]
df_1.loc[:,'Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
df_0 = df[df['Survived']==0]
df_0.loc[:,'Age']
# Out:
# 0      22.0
# 4      35.0
# 5      29.0
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888    29.0
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
plt.figure(figsize=(16,4))
plt.plot(df_1.loc[:,'Age'], color="b")
plt.plot(df_0.loc[:,'Age'], color="r")

# %% [markdown]
# ## 15. Muestra en una grafica de caja la edad de los que sobrevivieron y de los que no sobrevivieron
#
#
# Nota: Para poder graficarlo hay que reemplazar los NaN por el promedio de edad.

# %%
df['Age'] = df['Age'].replace(np.nan, int(df.Age.mean()) )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = [df_0.loc[:,'Age'], df_1.loc[:,'Age']]
et = ['No sobrevivieron', 'Sobrevivientes']
fig, ax = plt.subplots(figsize=(8,))
ax.boxplot(data, labels=et)
plt.show()

# %% [markdown]
# ## 16. Mostrar en una gráfica de caja por clase la edad de los pasajeros

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clase1 = df[df['Pclass']==1]
clase1 = clase1.loc[:,'Age']
clase1
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 216, dtype: float64

# %%
clase2 = df[df['Pclass']==2]
clase2 = clase2.loc[:,'Age']
clase2
clase3 = df[df['Pclass']==3]
clase3 = clase3.loc[:,'Age']
clase3
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5      29.0
# 7       2.0
#        ...
# 882    22.0
# 884    25.0
# 885    39.0
# 888    29.0
# 890    32.0
# Name: Age, Length: 491, dtype: float64

# %%
data1 = [clase1,clase2,clase3]
labels = ['Clase 1', 'Clase 2', 'Clase 3']
fig, ax = plt.subplots(figsize=(8,6))
plt.boxplot(data1, labels=labels)
plt.show()

# %% [markdown]
# ## 17. Muestra en una gráfica de dispersión (scatter) la edad de los pasajeros vs el costo de su ticket

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.loc[:,'Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    29.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.loc[:,'Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
plt.scatter(df.loc[:,'Age'],df.loc[:,'Fare'] , color='darkviolet')
plt.xlabel('Edades')  
plt.ylabel('Precio')  
plt.title('Edades vs Precios')
# Out:
# Text(0.5, 1.0, 'Edades vs Precios')

# %% [markdown]
# ## 18. Muestra en una gráfica de dispersión la clase vs el  el precio del ticket

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.scatter( df.loc[:,'Pclass'], df.loc[:,'Fare'], color = 'lightcoral')
plt.xlabel('class')
plt.ylabel('price ')
# Out:
# Text(0, 0.5, 'price ')

# %% [markdown]
# ## 19. Muestra en un histograma la edad de los pasajeros que sobrevivieron y la edad de los que no

# %%
df_si = df[df['Survived'] == 1]
df_si.loc[:,'Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
df_no = df[df['Survived'] == 0]
df_no.loc[:,'Age']
# Out:
# 0      22.0
# 4      35.0
# 5      29.0
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888    29.0
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
plt.hist(df_si.loc[:,'Age'], bins=30, alpha = 0.7, color = 'Green')
plt.hist(df_no.loc[:,'Age'], bins =30, alpha = 0.3, color = 'Red')

plt.show()

# %% [markdown]
# ## 20. Muestra en un histograma el costo de boleto por clase

# %%
dfprice1 = df[df['Pclass']==1]
dfprice1.loc[:,'Fare']
# Out:
# 1      71.2833
# 3      53.1000
# 6      51.8625
# 11     26.5500
# 23     35.5000
#         ...
# 871    52.5542
# 872     5.0000
# 879    83.1583
# 887    30.0000
# 889    30.0000
# Name: Fare, Length: 216, dtype: float64

# %%
dfprice1 = df[(df['Pclass']==1) & (df['Fare']< 200)]
dfprice1
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 6              7                            McCarthy, Mr. Timothy J    male
# 11            12                           Bonnell, Miss. Elizabeth  female
# 23            24                       Sloper, Mr. William Thompson    male
# ..           ...                                                ...     ...
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 872          873                           Carlsson, Mr. Frans Olof    male
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 887          888                       Graham, Miss. Margaret Edith  female
# 889          890                              Behr, Mr. Karl Howell    male
#
#       Age  Survived  Pclass    Ticket     Fare
# ...

# %%
dfprice2 = df[df['Pclass']==2]
dfprice2.loc[:,'Fare']
# Out:
# 9      30.0708
# 15     16.0000
# 17     13.0000
# 20     26.0000
# 21     13.0000
#         ...
# 866    13.8583
# 874    24.0000
# 880    26.0000
# 883    10.5000
# 886    13.0000
# Name: Fare, Length: 184, dtype: float64

# %%
dfprice3 = df[df['Pclass']==3]
dfprice3.loc[:,'Fare']
# Out:
# 0       7.2500
# 2       7.9250
# 4       8.0500
# 5       8.4583
# 7      21.0750
#         ...
# 882    10.5167
# 884     7.0500
# 885    29.1250
# 888    23.4500
# 890     7.7500
# Name: Fare, Length: 491, dtype: float64

# %%
dfprice3 = df[df['Pclass']==3]
#dfprice3['Fare']
dfprice3
# Out:
#      PassengerId                                      Name     Sex   Age  \
# 0              1                   Braund, Mr. Owen Harris    male  22.0
# 2              3                    Heikkinen, Miss. Laina  female  26.0
# 4              5                  Allen, Mr. William Henry    male  35.0
# 5              6                          Moran, Mr. James    male  29.0
# 7              8            Palsson, Master. Gosta Leonard    male   2.0
# ..           ...                                       ...     ...   ...
# 882          883              Dahlberg, Miss. Gerda Ulrika  female  22.0
# 884          885                    Sutehall, Mr. Henry Jr    male  25.0
# 885          886      Rice, Mrs. William (Margaret Norton)  female  39.0
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  female  29.0
# 890          891                       Dooley, Mr. Patrick    male  32.0
#
#      Survived  Pclass            Ticket     Fare
# ...

# %%
plt.title('Histograma de precios por clase ')
plt.hist(dfprice1.loc[:,'Fare'], color = 'gold')
plt.hist(dfprice2.loc[:, 'Fare'], color = 'lightgreen')
plt.hist(dfprice3.loc[:,'Fare'], color = 'pink')
plt.show()
