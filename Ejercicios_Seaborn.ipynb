# %% [markdown]
# # Ejercicios de visualización Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pokemon.loc[:,'Type 1'].value_counts(dropna = False)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# ## 1. Haz un diagrama de barras con el número de pokémons en cada generación

# %%
rgb_values = sns.color_palette("Set2", 6)
color_labels = pokemon['Generation'].unique()
color_map = dict(zip(color_labels, rgb_values))

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(pokemon['Generation'], palette=pokemon['Generation'].map(color_map)) #como value counts
plt.show()
# Out:
# C:\Users\zhuzh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pokemon['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(x = pokemon['Generation']) #como value counts
plt.show()

# %% [markdown]
# ## 2. Representar la frecuencia de pokémons por tipo 1 en un gráfico de barras.

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(x =pokemon['Type 1'], palette = 'tab10', data = pokemon)
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %%
plt.pie(valuecount.values, labels = pokemon['Type 1'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccd6986908>,
# ...
#  [Text(0.9953097568356063, 0.4683572225853324, 'Grass'),
#   Text(0.3316917441554607, 1.0487995932775283, 'Fire'),
#   Text(-0.38072877727881116, 1.0320104641677728, 'Water'),
#   Text(-0.8611676819228845, 0.6843904029218745, 'Bug'),
#   Text(-1.0828692258041388, 0.1933759028585134, 'Normal'),
#   Text(-1.0654414787782402, -0.27355886989611017, 'Poison'),
#   Text(-0.8899187028927927, -0.6465637650236902, 'Electric'),
#   Text(-0.6182917301180393, -0.9097886218609473, 'Ground'),
#   Text(-0.3234443784272165, -1.051372309918723, 'Fairy'),
#   Text(-0.05181712355688484, -1.0987788611482707, 'Fighting'),
#   Text(0.22306599161179438, -1.0771450985759752, 'Psychic'),
#   Text(0.48005013230807786, -0.9897231281883824, 'Rock'),
#   Text(0.6944880482385795, -0.8530453392720511, 'Ghost'),
#   Text(0.8611676578939139, -0.6843904331575005, 'Ice'),
#   Text(0.9859223117441397, -0.4878085640956826, 'Dragon'),
# ...

# %%
valuecount.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-634f96ad93a3> in <module>
# ----> 1 valuecount.values()
#
# AttributeError: 'function' object has no attribute 'values'

# %%
valuecount = pokemon['Type 1'].value_counts()
valuecount.values
# Out:
# array([112,  98,  70,  69,  57,  52,  44,  44,  32,  32,  32,  31,  28,
#         27,  27,  24,  17,   4], dtype=int64)

# %% [markdown]
# ## 3. Haz un diagrama de barras con el número de pokémons tipo 1 igual a "Grass" y "Fire"

# %%
ej3 = pokemon[pokemon['Type 1'].isin(['Grass','Fire'])] 
sns.countplot(x =ej3['Type 1'])
plt.show()

# %% [markdown]
# ## 4. Haz un histograma con los puntos de salud HP de los pokémons, utiliza el color verde

# %%
sns.displot(pokemon['HP'], color = 'Green')

# %%
plt.hist(pokemon['HP'], color = 'Green', bins = 20)
# Out:
# (array([  2.,   8.,  40., 162., 147., 189.,  94.,  92.,  38.,  12.,   5.,
#           5.,   2.,   1.,   1.,   0.,   0.,   0.,   0.,   2.]),
#  array([  1. ,  13.7,  26.4,  39.1,  51.8,  64.5,  77.2,  89.9, 102.6,
#         115.3, 128. , 140.7, 153.4, 166.1, 178.8, 191.5, 204.2, 216.9,
#         229.6, 242.3, 255. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## 5. Haz un histograma con la frecuencia de pokémons por rapidez (Speed).

# %%
sns.distplot(pokemon['Speed'], color = 'Magenta', kde_kws={"color": "b", "lw": 2, "label": "Speed"})
# Out:
# C:\Users\zhuzh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Speed', ylabel='Density'>

# %% [markdown]
# ## 6. Haz un histograma con los puntos de salud (HP) de los pokémons (Type 1) = "Fire"

# %%
sns.histplot(pokemon[pokemon['Type 1']=='Fire'].HP, bins=10, color = 'darkorange')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Count'>

# %%
sns.distplot(pokemon[pokemon['Type 1']=='Fire'].HP, bins=10, color = 'darkorange')
# Out:
# C:\Users\zhuzh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %% [markdown]
# ## 7. Haz un scatter plot y un hex plot con los valores de "Attack" y "Defense"de los pokémons

# %%
sns.color_palette("rocket", as_cmap=True)

# %%
sns.color_palette("magma")
# Out:
# [(0.135053, 0.068391, 0.315),
#  (0.372116, 0.092816, 0.499053),
#  (0.594508, 0.175701, 0.501241),
#  (0.828886, 0.262229, 0.430644),
#  (0.973381, 0.46152, 0.361965),
#  (0.997341, 0.733545, 0.505167)]

# %%
sns.jointplot(pokemon['Attack'], pokemon['Defense'])

# %%
sns.jointplot(pokemon['Attack'], pokemon['Defense'], kind = 'hex', color = 'magenta')

# %% [markdown]
# ## 8. Haz un scatter hex plot con los valores de "Attack" y "Defense"de los pokémons tipo "Water" y "Fire"

# %%
pokemon8 = pokemon[pokemon['Type 1'].isin(['Water','Fire'])]
pokemon8
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 762  692                  Clauncher  Water     NaN    330  50      53
# 763  693                  Clawitzer  Water     NaN    500  71      73
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# ...

# %%
sns.jointplot(x = pokemon8['Attack'], y =pokemon8['Defense'], kind = 'hex', color = 'pink')

# %% [markdown]
# ## 9. Haz un KDE plot con la salud y el ataque de los pokémons

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.kdeplot(x = pokemon['HP'], y= pokemon['Attack'], color = 'orangered')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
sns.jointplot(x = pokemon['HP'], y= pokemon['Attack'], color = 'orangered')

# %% [markdown]
# ## 10. Haz una grafica de caja con el ataque de los pokémons legendarios y no legendarios.

# %%
pokemon[pokemon['Legendary'] == True]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
sns.boxplot(x = 'Legendary', y = 'Attack', data = pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %% [markdown]
# ## 11. Haz una grafica de violin con el ataque de los pokémons legendarios y no legendarios.

# %%
sns.violinplot(x = 'Legendary', y = 'Attack', data = pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %% [markdown]
# ## 12.
#     1. Usando FacetGrid y obtén un KDE plot del ataque para legendarios y no legendarios.
#     1. Repite lo mismo, ahora separándolos también por generaciones en cada fila.

# %%
g = sns.FacetGrid(pokemon, col="Legendary")
g.map(sns.kdeplot, 'Attack', color = 'Green')

# %%
g = sns.FacetGrid(pokemon, col="Legendary", row='Generation')
g.map(sns.kdeplot,'Attack', color = 'orangered' )

# %% [markdown]
# ## 13. Haz un pairplot y compara los puntos de salud (HP), el ataque y la defensa de los pokémons.

# %%
sns.pairplot(pokemon, vars = ['HP', 'Attack','Defense'])

# %% [markdown]
# ## 14. Haz boxplots de la variable `'Total'` distiguiendo por generación y entre legendarios y no legendarios.

# %%
g = sns.FacetGrid(pokemon, col="Legendary", row='Generation')
g.map(sns.boxplot, 'Total', data = pokemon, color = 'yellow')
# Out:
# C:\Users\zhuzh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.boxplot(x='Legendary', y='Total', hue = 'Generation', data = pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Total'>

# %% [markdown]
# ## 15. Haz un heatmap para comparar la correlación entre salud, ataque, ataque especial, defensa, defensa especial y velocidad.

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.heatmap(pokemon[['HP','Attack','Sp. Atk', 'Defense', 'Sp. Def', 'Speed']].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 16. Encontrar los 5 mejores pokémons con respecto a la columna "Total", del tipo "Electric", "Fire", "Water" y comparar su salud, ataque, defensa y velocidad en un mapa de calor

# %%
pokemon16 =pokemon[pokemon['Type 1'].isin(['Electric','Fire','Water'])]
pokemon16
# Out:
#        #                       Name    Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander      Fire     NaN    309  39      52
# 5      5                 Charmeleon      Fire     NaN    405  58      64
# 6      6                  Charizard      Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634  78     104
# ..   ...                        ...       ...     ...    ...  ..     ...
# 763  693                  Clawitzer     Water     NaN    500  71      73
# 764  694                 Helioptile  Electric  Normal    289  44      38
# 765  695                  Heliolisk  Electric  Normal    481  62      55
# 772  702                    Dedenne  Electric   Fairy    431  67      58
# 799  721                  Volcanion      Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon16[pokemon16['Type 1']== 'Fire'].sort_values('Total', ascending= False ).head(5)
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 799  721                  Volcanion   Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 270       90      110      154     90           2       True
# 7        111      130       85    100           1      False
# 8         78      159      115    100           1      False
# 279       80      130       80    100           3      False
# 799      120      130       90     70           6       True

# %%
lista = []
for i in pokemon16['Type 1'].unique():
    df = pokemon16[pokemon16['Type 1']== i].sort_values('Total',ascending= False).head(5)
    lista.append(df)
poknew = pd.concat(lista,axis=0)
poknew
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 270  250                      Ho-oh      Fire    Flying    680  106     130
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 279  257      BlazikenMega Blaziken      Fire  Fighting    630   80     160
# 799  721                  Volcanion      Fire     Water    600   80     110
# 422  382        KyogrePrimal Kyogre     Water       NaN    770  100     150
# 541  484                     Palkia     Water    Dragon    680   90     120
# 421  382                     Kyogre     Water       NaN    670  100     100
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 283  260      SwampertMega Swampert     Water    Ground    635  100     150
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# ...

# %%
sns.heatmap(pokemon16[['HP','Attack', 'Defense', 'Speed']].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 17. Crear un poligono para 5 pokemons con sus caracteristicas

# %%
from scipy.stats import ttest_ind
ttest, pval = ttest_ind(pokemon.loc[pokemon['Legendary']==True, 'Attack'], pokemon.loc[pokemon['Legendary']==True, 'Attack'])
if pval <0.05:
    print("No podemos aceptar que sean iguales", col)
else:
    print("Son iguales", col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6e8240eebe09> in <module>
#       4     print("No podemos aceptar que sean iguales", col)
#       5 else:
# ----> 6     print("Son iguales", col)
#
# NameError: name 'col' is not defined
